# %%
pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install
# Out:
# ...
#      |████████████████████████████████| 20.9 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 479 kB 38.6 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 861 kB 46.0 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963394 sha256=191455d1da00b43cd513c69b6dbd473463f3279cc2828a6ba10780fe9200ebed
#   Stored in directory: /Users/shreyasprasad/Library/Caches/pip/wheels/4d/ba/f4/b8c0941055519ebc0f27e85bfe2bb223f1a59a3b8bfc5c7515
# ...
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465825 sha256=d8331fd7657460b6a5d177ca633fcfb76bffefb9eabadc553ba57e83ad333ec6
#   Stored in directory: /Users/shreyasprasad/Library/Caches/pip/wheels/e3/3a/b3/a709b437602c3807f079f0c35ccba3e1adf9af6f2e6b0ebfea
# Successfully built jupyter-latex-envs jupyter-nbextensions-configurator
# ...
