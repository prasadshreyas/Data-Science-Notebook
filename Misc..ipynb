# %% [markdown]
# # Misc Python

# %% [markdown]
# Nested Funtion:

# %%
def create_adder(x):
    def adder(y):
        return x + y
    return adder

# %%
create_adder
# Out:
# <function __main__.create_adder(x)>

# %%
add_1 = create_adder(1)
add_1
# Out:
# <function __main__.create_adder.<locals>.adder(y)>

# %%
type(add_1)
# Out:
# function

# %%
add_1(2)
# Out:
# 3

# %% [markdown]
# # Lambdas

# %%
def f(x):
    return x > 2
f(3)
# Out:
# True

# %%
(lambda x : x > 2)(3)
# Out:
# True

# %% [markdown]
# Underscore as a variable

# %%
(lambda _ : _ > 2)(3)
# Out:
# True

# %% [markdown]
# # Modules

# %%
# %%file some_module.py 

PI = 3.14159 # defining a variable

from numpy import arccos # importing a function from another module

def f(x): 
    """
    This is a function which adds 1 to its argument
     
    """
    return x + 1

def g(x, y): 
    """
    This is a function which sums its 2 arguments
    """
    return x + y
# Out:
# Writing some_module.py

# %%
# !pwd
# Out:
# /Users/shreyasprasad/Notebooks

# %%
import some_module

# %% [markdown]
# The magic `%whos` object (all objects preceded by % are called magic) gies us all the valiables we declared in the notebook or imported from external files!

# %%
# %whos
# Out:
# Variable       Type        Data/Info
# ------------------------------------
# add_1          function    <function create_adder.<l<...>.adder at 0x7fd2e8bc6ee0>
# create_adder   function    <function create_adder at 0x7fd2c80a4160>
# numpy          module      <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# obj            NoneType    None
# some_module    module      <module 'some_module' fro<...>otebooks/some_module.py'>

# %%
dir(some_module)
# Out:
# ['PI',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'arccos',
#  'f',
#  'g']

# %%
help(some_module)
# Out:
# Help on module some_module:
#
# NAME
#     some_module
#
# FUNCTIONS
#     f(x)
#         This is a function which adds 1 to its argument
#
#     g(x, y)
#         This is a function which sums its 2 arguments
#
# DATA
#     PI = 3.14159
#     arccos = <ufunc 'arccos'>
#
# FILE
#     /Users/shreyasprasad/Notebooks/some_module.py

# %%
some_module.PI
# Out:
# 3.14159

# %% [markdown]
# # Generators and ` yield`

# %%
# Sum of first n numbers:
def first_n(n):
    '''Build and return a list'''
    num, nums = 0, []
    while num < n:
        nums.append(num)
        num += 1
    return nums

print(sum(first_n(100)))
# Out:
# 4950

# %%
# a generator that yields items instead of returning a list
def firstn(n):
    num = 0
    while num < n:
        yield num
        num += 1
print(sum(firstn(100)))
# Out:
# 4950

# %% [markdown]
# ### Higher order funtions

# %%
a = [1,2,3]
b = [3,2,1]
c = zip(a,b)

# %%
list(c)
# Out:
# [(1, 3), (2, 2), (3, 1)]

# %%
list(map(max,a,b))
# Out:
# [3, 2, 3]

# %%
list(filter(lambda x: x > 5, [3, 4, 5, 6, 7]))
# Out:
# [6, 7]

# %% [markdown]
# Python's `*args` and `**kwargs` constructs lets you iterate over **positional arguments** and **named arguments**:

# %%
def f(*args, **kwargs):
    print ("unnamed args: ", args)
    print ("keyword args: ", kwargs)

# %%
f(1,2,3,a=4,b=5,c=6)
# Out:
# unnamed args:  (1, 2, 3)
# keyword args:  {'a': 4, 'b': 5, 'c': 6}

# %%
from fractions import Fraction

f = Fraction(3,4)
f
# Out:
# Fraction(3, 4)

# %%
print(type(f))
float(f)
# Out:
# <class 'fractions.Fraction'>
# 0.75

# %%
from itertools import combinations, combinations_with_replacement

list(combinations([1,2,3],2))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
combinations([1,2,3],2)

# %%
set(combinations([1,2,3,4,5],3))
# Out:
# {(1, 2, 3),
#  (1, 2, 4),
#  (1, 2, 5),
#  (1, 3, 4),
#  (1, 3, 5),
#  (1, 4, 5),
#  (2, 3, 4),
#  (2, 3, 5),
#  (2, 4, 5),
#  (3, 4, 5)}

# %%
l = list(combinations_with_replacement([1,2,3,4,5],3))
l[:5]
# Out:
# [(1, 1, 1), (1, 1, 2), (1, 1, 3), (1, 1, 4), (1, 1, 5)]

# %%
import random

random.sample(l,5)
# Out:
# [(1, 1, 2), (2, 2, 3), (3, 3, 4), (2, 2, 5), (2, 3, 4)]

# %%
from math import factorial

factorial(5)
# Out:
# 120

# %%
5*4*3*2*1
# Out:
# 120

# %% [markdown]
# ## Enumerate
#
# The enumerate object yields pairs containing a count (from start, which defaults to zero) and a value yielded by the iterable argument.

# %%
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i,v in [1,2,3]:
    print(i)
    print(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5w/646h07dx15l3rv4_5lf3zq3h0000gn/T/ipykernel_43586/725191065.py in <module>
# ----> 1 for i,v in [1,2,3]:
#       2     print(i)
#       3     print(v)
#
# TypeError: cannot unpack non-iterable int object

# %%
l = [1,2,3]
for i in range(len(l)):
    print(i, l[i])
# Out:
# 0 1
# 1 2
# 2 3

# %%
enumerate([1,2,3])

# %%
for i in enumerate([1,2,3]):
    print(i)
# Out:
# (0, 1)
# (1, 2)
# (2, 3)

# %% [markdown]
# ## Callable
# This built-in method in Python checks and returns True if the object passed appears to be callable, but may not be, otherwise False

# %%
callable("A")
# Out:
# False

# %%
callable(type("a"))
# Out:
# True
